# %% [markdown]
# <a href="https://colab.research.google.com/github/akshara2006-psit/Flyrank-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/akshara2006-psit/Flyrank-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Task Type
#
# Classification
#
# Goal:
# Predict whether a software engineering project is likely to be selected by recruiters as a high-quality portfolio project.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Target column:
#
# portfolio_quality
#
# Possible values
#
# High
# Medium
# Low
#
# or
#
# selected = 1
# not_selected = 0

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# For classification
#
# Accuracy
# Precision
# Recall
# F1 Score

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# Suppose every row represents one software project.

# %% [markdown]
# | project_name     | java | spring | ai | github_stars | deployed | selected |
# | ---------------- | ---- | ------ | -- | ------------ | -------- | -------- |
# | CollapseGuard AI | 1    | 1      | 1  | 24           | 1        | 1        |
# | Scam Detector    | 0    | 0      | 1  | 12           | 1        | 0        |
# | Todo App         | 1    | 0      | 0  | 2            | 0        | 0        |

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.DataFrame({
    "project_name": [
        "CollapseGuard AI",
        "Scam Detector",
        "Todo App"
    ],
    "java":[1,0,1],
    "spring":[1,0,0],
    "ai":[1,1,0],
    "github_stars":[24,12,2],
    "deployed":[1,1,0],
    "selected":[1,0,0]
})

df
# Out:
#        project_name  java  spring  ai  github_stars  deployed  selected
# 0  CollapseGuard AI     1       1   1            24         1         1
# 1     Scam Detector     0       0   1            12         1         0
# 2          Todo App     1       0   0             2         0         0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule cannot capture the complex relationship between technologies used, deployment quality, GitHub activity, documentation quality, and recruiter preferences. Machine learning can learn these patterns from historical examples and generalize to unseen projects.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
